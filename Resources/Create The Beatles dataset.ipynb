# %% [markdown]
# # Creation of The Beatles dataset
# We read sequentially all songs with the respective chords annontation, and we compute the chroma representation.
# The output will be a dataset where each row represent a frame of a song. For every frame we have the chroma representation, the title of the song and the annotated chord.
#
# This dataset can be usefuf to select the right hyperparameters for the template matching problem and to estimate its performance.

# %%
import os
import numpy as np
import librosa
import pandas as pd
import ntpath

# %%
# Functions to perform normalization and temporal smoothing on chroma (not used to build the dataset)
def normalize_2(chroma):
    chroma=chroma/np.sqrt(np.sum(chroma**2,axis=0))
    return chroma

def temporal_smothing(chroma,n_win):
    chroma_sm=np.zeros(shape=chroma.shape)
    chr_pd=librosa.util.pad_center(chroma,chroma.shape[1]+n_win, axis=1)
    for n in range(chroma.shape[1]):
        chroma_sm[:,n]=np.sum(chr_pd[:,n:(n+n_win)],axis=1)*1/n_win
    return chroma_sm

# %%
# Helper function that format the name of a music file as the name of the corresponding .lab file
def mp3_name_to_lab_name(mp3_name):
    return(mp3_name.split(sep=".")[0].replace(" ","_-_",1).replace(" ","_")+".lab")

# %%
# Example
mp3_name_to_lab_name("01 Come Together.mp3")
# Out:
# '01_-_Come_Together.lab'

# %%
# Parameters
n_fft=2048
hop_length=512*4

# %%
def read_lab_file(path,n_frames,sr,hop_length):
    df_curr=pd.read_csv(path,sep=" ",names=["start","end","chord"])
    row=0
    chords=[]
    for i in range(n_frames):
        curr=librosa.frames_to_time(i, sr=sr, hop_length=hop_length)
        if curr<df_curr["end"][row]:
            chords.append(df_curr["chord"][row])
        else:
            while curr>=df_curr["end"][row] and row < len(df_curr)-1:
                row=row+1
            chords.append(df_curr["chord"][row])
    return chords

# %%
# A function that given a song and a lab file produces the right dataset for the selected song

def analyze(song_path,lab_file_path,n_fft,hop_length):
    music,sr=librosa.load(song_path)
    chroma=librosa.feature.chroma_stft(y=music,sr=sr,norm=2,hop_length=hop_length,n_fft=n_fft,tuning=0,octwidth=None)
    df=pd.DataFrame(data=chroma.transpose(),columns=["C","C#","D","D#","E","F","F#","G","G#","A","A#","B"])
    df["title"]=ntpath.basename(song_path).split(sep=".")[0]
    n_frames=chroma.shape[1]
    df["chords"]=np.array(read_lab_file(lab_file_path,n_frames=n_frames,sr=sr,hop_length=hop_length))
    return df

# %%
# Example
song_example="..\\The Beatles Annotations\\Abbey Road\\01 Come Together.mp3"
lab_file_example="..\\The Beatles Annotations\\Abbey Road\\01_-_Come_Together.lab"
df_example=analyze(song_example,lab_file_example,n_fft=n_fft,hop_length=hop_length)
df_example[10:20]
# Out:
# C:\Users\franc\anaconda3\lib\site-packages\librosa\core\audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
#            C        C#         D        D#         E         F        F#  \
# 10  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 11  0.164133  0.224772  0.299246  0.229070  0.204288  0.218361  0.335546
# 12  0.190524  0.143558  0.167215  0.179474  0.145043  0.175821  0.262962
# 13  0.296210  0.466985  0.558658  0.455769  0.258379  0.161628  0.093561
# 14  0.323726  0.444969  0.567656  0.484239  0.244492  0.100534  0.037673
# 15  0.304459  0.450407  0.584635  0.491023  0.235431  0.094251  0.032250
# 16  0.349402  0.425618  0.515009  0.447726  0.267525  0.153345  0.090296
# 17  0.264295  0.426460  0.593802  0.517946  0.263125  0.119364  0.051197
# 18  0.266759  0.462203  0.612621  0.498210  0.216388  0.084445  0.030100
# 19  0.288460  0.446350  0.599387  0.502695  0.224541  0.081750  0.026751
#
#            G        G#         A        A#         B             title chords
# 10  0.000000  0.000000  0.000000  0.000000  0.000000  01 Come Together      N
# 11  0.402079  0.434701  0.391124  0.223969  0.157283  01 Come Together      N
# 12  0.373328  0.494295  0.480767  0.312176  0.222551  01 Come Together      N
# 13  0.050437  0.046526  0.068266  0.132601  0.213940  01 Come Together  D:min
# 14  0.012695  0.013773  0.039058  0.115308  0.232398  01 Come Together  D:min
# 15  0.007867  0.008366  0.031853  0.101919  0.211310  01 Come Together  D:min
# 16  0.089611  0.095321  0.097818  0.157384  0.276375  01 Come Together  D:min
# 17  0.021581  0.016359  0.032833  0.088630  0.177880  01 Come Together  D:min
# 18  0.007840  0.007037  0.025549  0.081543  0.171511  01 Come Together  D:min
# 19  0.007453  0.007484  0.028353  0.093118  0.195427  01 Come Together  D:min

# %%
# Building the dataset
first=1
for root, dirs, files in os.walk("..\\The Beatles Annotations"):
    print("Scanning folder:\n"+root)
    notadded=[]
    for file in files:
        if file.endswith(".mp3"):
            print(root+"\\"+file,end="\t")
            if os.path.isfile(root+"\\"+mp3_name_to_lab_name(file)):
                if first:
                    df=analyze(song_path=root+"\\"+file,lab_file_path=root+"\\"+mp3_name_to_lab_name(file),n_fft=n_fft,hop_length=hop_length)
                    first=0
                else:
                    temp=analyze(song_path=root+"\\"+file,lab_file_path=root+"\\"+mp3_name_to_lab_name(file),n_fft=n_fft,hop_length=hop_length)
                    df=df.append(temp,ignore_index=True)
                print("*")
            else:
                print(".lab file does not exist!")
                notadded=notadded+[root+"\\"+file]
# Out:
# Scanning folder:
# ..\The Beatles Annotations
# Scanning folder:
# ..\The Beatles Annotations\A Hard Day's Night
# ..\The Beatles Annotations\A Hard Day's Night\01 A Hard Day's Night.mp3
# C:\Users\franc\anaconda3\lib\site-packages\librosa\core\audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# *
# ..\The Beatles Annotations\A Hard Day's Night\02 I Should Have Known Better.mp3	*
# ..\The Beatles Annotations\A Hard Day's Night\03 If I Fell.mp3	*
# ..\The Beatles Annotations\A Hard Day's Night\04 I'm Happy Just To Dance With You.mp3	*
# ..\The Beatles Annotations\A Hard Day's Night\05 And I Love Her.mp3	*
# ..\The Beatles Annotations\A Hard Day's Night\06 Tell Me Why.mp3	*
# ..\The Beatles Annotations\A Hard Day's Night\07 Can't Buy Me Love.mp3	*
# ..\The Beatles Annotations\A Hard Day's Night\08 Any Time At All.mp3	*
# ..\The Beatles Annotations\A Hard Day's Night\09 I'll Cry Instead.mp3	*
# ..\The Beatles Annotations\A Hard Day's Night\10 Things We Said Today.mp3	*
# ..\The Beatles Annotations\A Hard Day's Night\11 When I Get Home.mp3	*
# ..\The Beatles Annotations\A Hard Day's Night\12 You Can't Do That.mp3	*
# ..\The Beatles Annotations\A Hard Day's Night\13 I'll Be Back.mp3	*
# Scanning folder:
# ..\The Beatles Annotations\Abbey Road
# ..\The Beatles Annotations\Abbey Road\01 Come Together.mp3	*
# ..\The Beatles Annotations\Abbey Road\02 Something.mp3	*
# ..\The Beatles Annotations\Abbey Road\03 Maxwell's Silver Hammer.mp3	*
# ..\The Beatles Annotations\Abbey Road\04 Oh! Darling.mp3	*
# ..\The Beatles Annotations\Abbey Road\05 Octopus's Garden.mp3	*
# ..\The Beatles Annotations\Abbey Road\06 I Want You.mp3	*
# ..\The Beatles Annotations\Abbey Road\07 Here Comes The Sun.mp3	*
# ..\The Beatles Annotations\Abbey Road\08 Because.mp3	*
# ..\The Beatles Annotations\Abbey Road\09 You Never Give Me Your Money.mp3	*
# ..\The Beatles Annotations\Abbey Road\10 Sun King.mp3	*
# ..\The Beatles Annotations\Abbey Road\11 Mean Mr Mustard.mp3	*
# ..\The Beatles Annotations\Abbey Road\12 Polythene Pam.mp3	*
# ..\The Beatles Annotations\Abbey Road\13 She Came In Through The Bathroom Window.mp3	*
# ..\The Beatles Annotations\Abbey Road\14 Golden Slumbers.mp3	*
# ..\The Beatles Annotations\Abbey Road\15 Carry That Weight.mp3	*
# ..\The Beatles Annotations\Abbey Road\16 The End.mp3	*
# ..\The Beatles Annotations\Abbey Road\17 Her Majesty.mp3	*
# Scanning folder:
# ..\The Beatles Annotations\Beatles For Sale
# ..\The Beatles Annotations\Beatles For Sale\01 No Reply.mp3	*
# ..\The Beatles Annotations\Beatles For Sale\02 I'm A Loser.mp3	*
# ..\The Beatles Annotations\Beatles For Sale\03 Baby's In Black.mp3	*
# ..\The Beatles Annotations\Beatles For Sale\04 Rock And Roll Music.mp3	*
# ..\The Beatles Annotations\Beatles For Sale\05 I'll Follow The Sun.mp3	*
# ..\The Beatles Annotations\Beatles For Sale\06 Mr. Moonlight.mp3	.lab file does not exist!
# ..\The Beatles Annotations\Beatles For Sale\07 Kansas City- Hey, Hey, Hey, Hey.mp3	*
# ..\The Beatles Annotations\Beatles For Sale\08 Eight Days a Week.mp3	*
# ..\The Beatles Annotations\Beatles For Sale\09 Words of Love.mp3	*
# ..\The Beatles Annotations\Beatles For Sale\10 Honey Don't.mp3	*
# ..\The Beatles Annotations\Beatles For Sale\11 Every Little Thing.mp3	*
# ..\The Beatles Annotations\Beatles For Sale\12 I Don't Want to Spoil the Party.mp3	*
# ..\The Beatles Annotations\Beatles For Sale\13 What You're Doing.mp3	*
# ..\The Beatles Annotations\Beatles For Sale\14 Everybody's Trying to Be My Baby.mp3	*
# Scanning folder:
# ..\The Beatles Annotations\Help!
# ..\The Beatles Annotations\Help!\01 Help!.mp3	*
# ..\The Beatles Annotations\Help!\02 The Night Before.mp3	*
# ..\The Beatles Annotations\Help!\03 You've Got To Hide Your Love Away.mp3	*
# ..\The Beatles Annotations\Help!\04 I Need You.mp3	*
# ..\The Beatles Annotations\Help!\05 Another Girl.mp3	*
# ..\The Beatles Annotations\Help!\06 You're Going To Lose That Girl.mp3	*
# ..\The Beatles Annotations\Help!\07 Ticket To Ride.mp3	*
# ..\The Beatles Annotations\Help!\08 Act Naturally.mp3	*
# ..\The Beatles Annotations\Help!\09 It's Only Love.mp3	*
# ..\The Beatles Annotations\Help!\10 You Like Me Too Much.mp3	*
# ..\The Beatles Annotations\Help!\11 Tell Me What You See.mp3	*
# ..\The Beatles Annotations\Help!\12 I've Just Seen a Face.mp3	*
# ..\The Beatles Annotations\Help!\13 Yesterday.mp3	*
# ..\The Beatles Annotations\Help!\14 Dizzy Miss Lizzy.mp3	*
# Scanning folder:
# ..\The Beatles Annotations\Let It Be
# ..\The Beatles Annotations\Let It Be\01 Two of Us.mp3	*
# ..\The Beatles Annotations\Let It Be\02 Dig a Pony.mp3	*
# ..\The Beatles Annotations\Let It Be\03 Across the Universe.mp3	*
# ..\The Beatles Annotations\Let It Be\04 I Me Mine.mp3	*
# ..\The Beatles Annotations\Let It Be\05 Dig It.mp3	*
# ..\The Beatles Annotations\Let It Be\06 Let It Be.mp3	*
# ..\The Beatles Annotations\Let It Be\07 Maggie Mae.mp3	*
# ..\The Beatles Annotations\Let It Be\08 I've Got A Feeling.mp3	*
# ..\The Beatles Annotations\Let It Be\09 One After 909.mp3	*
# ..\The Beatles Annotations\Let It Be\10 The Long and Winding Road.mp3	*
# ..\The Beatles Annotations\Let It Be\11 For You Blue.mp3	*
# ..\The Beatles Annotations\Let It Be\12 Get Back.mp3	*
# Scanning folder:
# ..\The Beatles Annotations
# ..\The Beatles Annotations\Rubber Soul\09 Girl.mp3	*
# ..\The Beatles Annotations\Rubber Soul\10 I'm Looking Through You.mp3	*
# ..\The Beatles Annotations\Rubber Soul\11 In My Life.mp3	*
# ..\The Beatles Annotations\Rubber Soul\12 Wait.mp3	*
# ..\The Beatles Annotations\Rubber Soul\13 If I Needed Someone.mp3	*
# ..\The Beatles Annotations\Rubber Soul\14 Run For Your Life.mp3	*
# Scanning folder:
# ..\The Beatles Annotations\Sgt. Pepper's Lonely Hearts Club Band
# ..\The Beatles Annotations\Sgt. Pepper's Lonely Hearts Club Band\01 Sgt. Pepper's Lonely Hearts Club Band.mp3	.lab file does not exist!
# ..\The Beatles Annotations\Sgt. Pepper's Lonely Hearts Club Band\02 With A Little Help From My Friends.mp3	*
# ..\The Beatles Annotations\Sgt. Pepper's Lonely Hearts Club Band\03 Lucy In The Sky With Diamonds.mp3	*
# ..\The Beatles Annotations\Sgt. Pepper's Lonely Hearts Club Band\04 Getting Better.mp3	*
# ..\The Beatles Annotations\Sgt. Pepper's Lonely Hearts Club Band\05 Fixing A Hole.mp3	*
# ..\The Beatles Annotations\Sgt. Pepper's Lonely Hearts Club Band\06 She's Leaving Home.mp3	*
# ..\The Beatles Annotations\Sgt. Pepper's Lonely Hearts Club Band\07 Being For The Benefit Of Mr. Kite.mp3	.lab file does not exist!
# ..\The Beatles Annotations\Sgt. Pepper's Lonely Hearts Club Band\08 Within You Without You.mp3	*
# ..\The Beatles Annotations\Sgt. Pepper's Lonely Hearts Club Band\09 When I'm Sixty-Four.mp3	*
# ..\The Beatles Annotations\Sgt. Pepper's Lonely Hearts Club Band\10 Lovely Rita.mp3	*
# ..\The Beatles Annotations\Sgt. Pepper's Lonely Hearts Club Band\11 Good Morning Good Morning.mp3	*
# ..\The Beatles Annotations\Sgt. Pepper's Lonely Hearts Club Band\12 Sgt. Pepper's Lonely Hearts Club Band (Reprise).mp3	.lab file does not exist!
# ..\The Beatles Annotations\Sgt. Pepper's Lonely Hearts Club Band\13 A Day In The Life.mp3	*
# Scanning folder:
# ..\The Beatles Annotations\The Beatles (White Album)
# Scanning folder:
# ..\The Beatles Annotations\The Beatles (White Album)\The Beatles (White Album) [Disc 1]
# ..\The Beatles Annotations\The Beatles (White Album)\The Beatles (White Album) [Disc 1]\CD1_-_01 Back in the USSR.mp3	*
# ..\The Beatles Annotations\The Beatles (White Album)\The Beatles (White Album) [Disc 1]\CD1_-_02 Dear Prudence.mp3	*
# ..\The Beatles Annotations\The Beatles (White Album)\The Beatles (White Album) [Disc 1]\CD1_-_03 Glass Onion.mp3	*
# ..\The Beatles Annotations\The Beatles (White Album)\The Beatles (White Album) [Disc 1]\CD1_-_04 Ob-La-Di, Ob-La-Da.mp3	*
# ..\The Beatles Annotations\The Beatles (White Album)\The Beatles (White Album) [Disc 1]\CD1_-_05 Wild Honey Pie.mp3	*
# ..\The Beatles Annotations\The Beatles (White Album)\The Beatles (White Album) [Disc 1]\CD1_-_06 The Continuing Story of Bungalow Bill.mp3	*
# ..\The Beatles Annotations\The Beatles (White Album)\The Beatles (White Album) [Disc 1]\CD1_-_07 While My Guitar Gently Weeps.mp3	*
# ..\The Beatles Annotations\The Beatles (White Album)\The Beatles (White Album) [Disc 1]\CD1_-_08 Happiness is a Warm Gun.mp3	*
# ..\The Beatles Annotations\The Beatles (White Album)\The Beatles (White Album) [Disc 1]\CD1_-_09 Martha My Dear.mp3	*
# ..\The Beatles Annotations\The Beatles (White Album)\The Beatles (White Album) [Disc 1]\CD1_-_10 I'm So Tired.mp3	*
# ..\The Beatles Annotations\The Beatles (White Album)\The Beatles (White Album) [Disc 1]\CD1_-_11 Black Bird.mp3	*
# ..\The Beatles Annotations\The Beatles (White Album)\The Beatles (White Album) [Disc 1]\CD1_-_12 Piggies.mp3	*
# ..\The Beatles Annotations\The Beatles (White Album)\The Beatles (White Album) [Disc 1]\CD1_-_13 Rocky Raccoon.mp3	*
# ..\The Beatles Annotations\The Beatles (White Album)\The Beatles (White Album) [Disc 1]\CD1_-_14 Don't Pass Me By.mp3	*
# ..\The Beatles Annotations\The Beatles (White Album)\The Beatles (White Album) [Disc 1]\CD1_-_15 Why Don't We Do It In The Road_.mp3	.lab file does not exist!
# ..\The Beatles Annotations\The Beatles (White Album)\The Beatles (White Album) [Disc 1]\CD1_-_16 I Will.mp3	*
# ..\The Beatles Annotations\The Beatles (White Album)\The Beatles (White Album) [Disc 1]\CD1_-_17 Julia.mp3	*
# Scanning folder:
# ..\The Beatles Annotations\The Beatles (White Album)\The Beatles (White Album) [Disc 2]
# ..\The Beatles Annotations\The Beatles (White Album)\The Beatles (White Album) [Disc 2]\CD2_-_01 Birthday.mp3	*
# ..\The Beatles Annotations\The Beatles (White Album)\The Beatles (White Album) [Disc 2]\CD2_-_02 Yer Blues.mp3	*
# ..\The Beatles Annotations\The Beatles (White Album)\The Beatles (White Album) [Disc 2]\CD2_-_03 Mother Nature's Son.mp3	*
# ..\The Beatles Annotations\The Beatles (White Album)\The Beatles (White Album) [Disc 2]\CD2_-_04 Everybody's Got Something To Hide Except Me and My Monkey.mp3	*
# ..\The Beatles Annotations\The Beatles (White Album)\The Beatles (White Album) [Disc 2]\CD2_-_05 Sexy Sadie.mp3	*
# ..\The Beatles Annotations\The Beatles (White Album)\The Beatles (White Album) [Disc 2]\CD2_-_06 Helter Skelter.mp3	*
# ..\The Beatles Annotations\The Beatles (White Album)\The Beatles (White Album) [Disc 2]\CD2_-_07 Long Long Long.mp3	*
# ..\The Beatles Annotations\The Beatles (White Album)\The Beatles (White Album) [Disc 2]\CD2_-_08 Revolution 1.mp3	*
# ..\The Beatles Annotations\The Beatles (White Album)\The Beatles (White Album) [Disc 2]\CD2_-_09 Honey Pie.mp3	*
# ..\The Beatles Annotations\The Beatles (White Album)\The Beatles (White Album) [Disc 2]\CD2_-_10 Savoy Truffle.mp3	*
# ..\The Beatles Annotations\The Beatles (White Album)\The Beatles (White Album) [Disc 2]\CD2_-_11 Cry Baby Cry.mp3	*
# ..\The Beatles Annotations\The Beatles (White Album)\The Beatles (White Album) [Disc 2]\CD2_-_12 Revolution 9.mp3	*
# ..\The Beatles Annotations\The Beatles (White Album)\The Beatles (White Album) [Disc 2]\CD2_-_13 Good Night.mp3	*
# Scanning folder:
# ..\The Beatles Annotations\With The Beatles
# ..\The Beatles Annotations\With The Beatles\01 It Won't Be Long.mp3	*
# ..\The Beatles Annotations\With The Beatles\02 All I've Got To Do.mp3	*
# ..\The Beatles Annotations\With The Beatles\03 All My Loving.mp3	*
# ..\The Beatles Annotations\With The Beatles\04 Don't Bother Me.mp3	*
# ..\The Beatles Annotations\With The Beatles\05 Little Child.mp3	*
# ..\The Beatles Annotations\With The Beatles\06 Till There Was You.mp3	*
# ..\The Beatles Annotations\With The Beatles\07 Please Mister Postman.mp3	*
# ..\The Beatles Annotations\With The Beatles\08 Roll Over Beethoven.mp3	*
# ..\The Beatles Annotations\With The Beatles\09 Hold Me Tight.mp3	*
# ..\The Beatles Annotations\With The Beatles\10 You Really Got A Hold On Me.mp3	*
# ..\The Beatles Annotations\With The Beatles\11 I Wanna Be Your Man.mp3	*
# ..\The Beatles Annotations\With The Beatles\12 Devil In Her Heart.mp3	*
# ..\The Beatles Annotations\With The Beatles\13 Not A Second Time.mp3	*
# ..\The Beatles Annotations\With The Beatles\14 Money.mp3	*

# %%
# Save dataset to csv file
df.to_csv(r'..\The Beatles dataset.csv', index = False)
